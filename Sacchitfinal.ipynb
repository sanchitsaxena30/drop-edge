# %%
# !git clone https://github.com/shahasifbashir/Drop.git
# Out:
# Cloning into 'Drop'...
# remote: Enumerating objects: 37, done.
# remote: Counting objects: 100% (37/37), done.
# remote: Compressing objects: 100% (28/28), done.
# remote: Total 37 (delta 10), reused 30 (delta 7), pack-reused 0
# Unpacking objects: 100% (37/37), done.

# %%
# %cd Drop/
# Out:
# /content/Drop

# %%
# !pip install tensorboardX

# %%
# !sh run.sh
# Out:
# Namespace(aggrmethod='default', datapath='data//', dataset='cora', debug=True, dropout=0.5, early_stopping=400, epochs=400, fastmode=False, hidden=128, inputlayer='gcn', lr=0.01, lradjust=False, mixmode=False, nbaseblocklayer=6, nhiddenlayer=1, no_cuda=False, no_tensorboard=False, normalization='AugNormAdj', outputlayer='gcn', sampling_percent=0.05, seed=42, task_type='full', type='inceptiongcn', warm_start='', weight_decay=0.001, withbn=False, withloop=False)
# Load full supervised task.
# nclass: 7	nfea:1433
# Model is saving to: tmpmodel/tmp-0622-102443-mVJ.pt
# Epoch: 0001 loss_train: 2.0561 acc_train: 0.1440 loss_val: 2.6503 acc_val: 0.2940 cur_lr: 0.01000 s_time: 0.0224s t_time: 0.5238s v_time: 0.1097s
# Epoch: 0002 loss_train: 2.9002 acc_train: 0.2914 loss_val: 1.8764 acc_val: 0.2940 cur_lr: 0.01000 s_time: 0.0038s t_time: 0.2827s v_time: 0.1070s
# ...
